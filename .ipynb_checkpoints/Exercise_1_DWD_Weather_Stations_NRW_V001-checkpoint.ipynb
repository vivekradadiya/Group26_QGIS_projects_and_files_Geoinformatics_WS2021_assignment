# %% [markdown]
# # Get Station Description for DWD Climatologial Measuring Stations

# %% [markdown]
# ## 1. About the DWD Open Data Portal
#
# The data of the Climate Data Center (CDC) of the DWD (Deutscher Wetterdienst, German Weather Service) is provided on an **FTP server**. <br> **FTP** stands for _File Transfer Protocol_.
#
# Open the FTP link ftp://opendata.dwd.de/climate_environment/CDC/ in your browser (copy-paste) and find our how it is structured hierarchically.
#
# You can also open the link with **HTTPS** (Hypertext Transfer Protocol Secure): https://opendata.dwd.de/climate_environment/CDC/
#
# **Download and read** the document https://opendata.dwd.de/climate_environment/CDC/Readme_intro_CDC_ftp.pdf
#
# **Q1:** In which temporal resolutions are the time series provided?
#
# **Q2:** What is the difference between _historical_ and _recent_ data also with respect to quality control?
#
# **Q3:** Are all meteorological parameters provided at the same temporal resolution?

# %% [markdown]
# ## 2. Download the Station Meta Data
#
# We are interested in observations with following properties:
#
# 1. The observations are taken in Germany.
# 1. It is precipitation data.
# 1. The temporal resolution is hourly.
# 1. Use recent data, not historical.
#
#
# Download the corresonding station meta data file (description) from the FTP server. The file you have to download is named `RR_Stundenwerte_Beschreibung_Stationen.txt`. The elements of the file name denote:
#
# * RR, Regenrate: Precipitation Rate
# * Jahreswerte:   Annual Values,
# * Beschreibung:  Description,
# * Stationen:     Stations
#
# **Q1:** Under with path (directory, folder) on the FTP server do you find the file?
#
# **Q2:** The Python FTP client we use is provided through the library _ftplib_: <br>
# https://pythonprogramming.net/ftp-transfers-python-ftplib/ <br>
# How to you use it?
#
# **Q3:** Look at the code below. In which folder is the data stored locally? What is are relative and absolute paths?

# %% [markdown]
# ## FTP Connection
#
# This connection is used to download the metadata text file `RR_Stundenwerte_Beschreibung_Stationen.txt` listing the meteorological stations providing hourly precipitation measurements. The data in the text file is fixed width formatted, i.e. data is nicely arranged in columns. Several of the stations have been already abandoned. Whether the precipitation measurements are still active can be concluded from the column `bis_datum`. Of course you could have downloaded this single file directly by means of your browser or an FTP client but later it becomes clear how download processes can be automized with the ftplib.

# %% [markdown]
# ### Connection Parameters
#
# FTP servers often provide an anonymous access such that no personal login is required.

# %%
# FTP server credentials for the CDC (Climate Data Center) data of the DWD (Deutscher Wetterdienst, German Weather Service).
server = "opendata.dwd.de"
user   = "anonymous"
passwd = ""

# %% [markdown]
# ### FTP Directory Definition and Station Description Filename Pattern

# %%
# The topic of interest: historical hourly precipitation data.
topic_dir = "/hourly/precipitation/historical/"

# This is the search pattern common to ALL station description file names. 
station_desc_pattern = "_Beschreibung_Stationen.txt"

# Below this directory tree node all climate data are stored.
climate_data_dir = "/climate_environment/CDC/observations_germany/climate"
ftp_dir =  climate_data_dir + topic_dir

# %% [markdown]
# ### Local Directories

# %%
# To keep the folders tidy the subdirectory tree of the FTP is replicated.
local_ts_dir = "data/generated/DWD" + topic_dir # TS stands for "time series". Better add a trailing "/" to make life easier ... 
local_station_dir = local_ts_dir # station info directory.

# %%
# Directory trees are created. Ignore errors if they already exist.
import os
os.makedirs(local_ts_dir,exist_ok = True) # it does not complain if the dir already exists.
os.makedirs(local_station_dir,exist_ok = True) # it does not complain if the dir already exists.

# %% [markdown]
# ### FTP Connect

# %%
# Open the FTP session. Log in. If the connection idles for too long it will time out.
import ftplib
ftp = ftplib.FTP(server)
res = ftp.login(user=user, passwd = passwd)
print(res)
# Out:
# 230 Login successful.

# %%
# Just check, whether the connection is still open (not having reached a timeout yes)
ret = ftp.cwd(".")

# %%
# How to log out.
#ftp.quit()

# %% [markdown]
# ### FTP Grab File Function

# %%
def grabFile(ftpfullname,localfullname):
    try:
        ret = ftp.cwd(".") # A dummy action to check the connection and to provoke an exception if necessary.
        localfile = open(localfullname, 'wb')
        ftp.retrbinary('RETR ' + ftpfullname, localfile.write, 1024)
        localfile.close()
    
    except ftplib.error_perm:
        print("FTP ERROR. Operation not permitted. File not found?")

    except ftplib.error_temp:
        print("FTP ERROR. Timeout.")

    except ConnectionAbortedError:
        print("FTP ERROR. Connection aborted.")

# %% [markdown]
# ### Generate Pandas Dataframe from FTP Directory Listing

# %%
import pandas as pd
import os

# generate a pandas dataframe from a FTP directory listing. 
def gen_df_from_ftp_dir_listing(ftp, ftpdir):
    lines = []
    flist = []
    try:
        # issue the command LIST in the FTP connection 
        res = ftp.retrlines("LIST "+ftpdir, lines.append)
    except:
        print("Error: ftp.retrlines() failed. ftp timeout? Reconnect!")
        return
        
    if len(lines) == 0:
        print("Error: ftp dir is empty")
        return
    
    for line in lines:
        print(line)
        [ftype, fsize, fname] = [line[0:1], int(line[31:42]), line[56:]]
        
        fext = os.path.splitext(fname)[-1]
        
        if fext == ".zip":
            station_id = int(fname.split("_")[2])
        else:
            station_id = -1 
        
        flist.append([station_id, fname, fext, fsize, ftype])
        
        

    df_ftpdir = pd.DataFrame(flist,columns=["station_id", "name", "ext", "size", "type"])
    return(df_ftpdir)

# %%
# Generate a pandas dataframe from the FTP directory listing 
df_ftpdir = gen_df_from_ftp_dir_listing(ftp, ftp_dir)
# Out:
# -rw-r--r--    1 9261     15101       71445 Mar 30  2020 BESCHREIBUNG_obsgermany_climate_hourly_precipitation_historical_de.pdf
# -rw-r--r--    1 9261     15101       69716 Mar 30  2020 DESCRIPTION_obsgermany_climate_hourly_precipitation_historical_en.pdf
# -rw-r--r--    1 9261     15101      209079 Feb 16 09:18 RR_Stundenwerte_Beschreibung_Stationen.txt
# -rw-r--r--    1 9261     15101      419265 Jan 13 08:29 stundenwerte_RR_00003_19950901_20110401_hist.zip
# -rw-r--r--    1 9261     15101      407378 Jan 13 08:29 stundenwerte_RR_00020_20040814_20191231_hist.zip
# -rw-r--r--    1 9261     15101      320516 Jan 13 08:29 stundenwerte_RR_00044_20070401_20191231_hist.zip
# -rw-r--r--    1 9261     15101      361931 Jan 13 08:29 stundenwerte_RR_00053_20051001_20191231_hist.zip
# -rw-r--r--    1 9261     15101      402880 Jan 13 08:29 stundenwerte_RR_00071_20041022_20191231_hist.zip
# -rw-r--r--    1 9261     15101      333070 Jan 13 08:29 stundenwerte_RR_00073_20070401_20191231_hist.zip
# -rw-r--r--    1 9261     15101      384729 Jan 13 08:29 stundenwerte_RR_00078_20041101_20191231_hist.zip
# -rw-r--r--    1 9261     15101      379869 Jan 13 08:30 stundenwerte_RR_00087_20050201_20191231_hist.zip
# -rw-r--r--    1 9261     15101      394972 Jan 13 08:29 stundenwerte_RR_00091_20040901_20191231_hist.zip
# -rw-r--r--    1 9261     15101      402997 Jan 13 08:29 stundenwerte_RR_00103_20040701_20191231_hist.zip
# -rw-r--r--    1 9261     15101
_20191231_hist.zip
# -rw-r--r--    1 9261     15101      260340 Jan 13 08:29 stundenwerte_RR_14157_20091201_20191231_hist.zip
# -rw-r--r--    1 9261     15101      252079 Jan 13 08:29 stundenwerte_RR_15000_20110401_20191231_hist.zip
# -rw-r--r--    1 9261     15101      216509 Jan 13 08:29 stundenwerte_RR_15003_20110501_20191231_hist.zip
# -rw-r--r--    1 9261     15101      166610 Jan 13 08:29 stundenwerte_RR_15207_20131101_20191231_hist.zip
# -rw-r--r--    1 9261     15101      144713 Jan 13 08:29 stundenwerte_RR_15444_20140901_20191231_hist.zip
# -rw-r--r--    1 9261     15101      126658 Jan 13 08:29 stundenwerte_RR_15478_20150201_20191231_hist.zip
# -rw-r--r--    1 9261     15101       81166 Jan 13 08:29 stundenwerte_RR_15490_20161201_20191231_hist.zip
# -rw-r--r--    1 9261     15101       83934 Jan 13 08:29 stundenwerte_RR_15512_20160901_20191231_hist.zip
# -rw-r--r--    1 9261     15101       56846 Jan 13 08:29 stundenwerte_RR_15514_20171101_20191231_hist.zip
# -rw-r--r--    1 9261     15101       95314 Jan 13 08:29 stundenwerte_RR_15555_20160501_20191231_hist.zip

# %% [markdown]
# Read the following output carefully. <br>
# Q: What does `station_id = -1` mean? <br>
# Q: What does the field `ext` mean? <br>
# Q: What is the name of the file describing the stations, i.e. lists the stations with their names, coordinates, and other attributes?

# %%
df_ftpdir.head(10)
# Out:
#    station_id                                               name   ext  \
# 0          -1  BESCHREIBUNG_obsgermany_climate_hourly_precipi...  .pdf
# 1          -1  DESCRIPTION_obsgermany_climate_hourly_precipit...  .pdf
# 2          -1         RR_Stundenwerte_Beschreibung_Stationen.txt  .txt
# 3           3   stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip
# 4          20   stundenwerte_RR_00020_20040814_20191231_hist.zip  .zip
# 5          44   stundenwerte_RR_00044_20070401_20191231_hist.zip  .zip
# 6          53   stundenwerte_RR_00053_20051001_20191231_hist.zip  .zip
# 7          71   stundenwerte_RR_00071_20041022_20191231_hist.zip  .zip
# 8          73   stundenwerte_RR_00073_20070401_20191231_hist.zip  .zip
# 9          78   stundenwerte_RR_00078_20041101_20191231_hist.zip  .zip
#
#      size type
# 0   71445    -
# 1   69716    -
# 2  209079    -
# 3  419265    -
# 4  407378    -
# 5  320516    -
# 6  361931    -
# 7  402880    -
# 8  333070    -
# 9  384729    -

# %% [markdown]
# ### Dataframe with TS Zip Files
#
# Create a dataframe with the names of the zip files only. These zip archives contain the real measurement data. The measured variable (precipitation, temoperature, etc.) is time dependent. A sequence of data over time is called **time series**.

# %%
#df_ftpdir["ext"]==".zip"
df_zips = df_ftpdir[df_ftpdir["ext"]==".zip"]
df_zips.set_index("station_id", inplace = True)
df_zips.head(10)
# Out:
#                                                         name   ext    size  \
# station_id
# 3           stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip  419265
# 20          stundenwerte_RR_00020_20040814_20191231_hist.zip  .zip  407378
# 44          stundenwerte_RR_00044_20070401_20191231_hist.zip  .zip  320516
# 53          stundenwerte_RR_00053_20051001_20191231_hist.zip  .zip  361931
# 71          stundenwerte_RR_00071_20041022_20191231_hist.zip  .zip  402880
# 73          stundenwerte_RR_00073_20070401_20191231_hist.zip  .zip  333070
# 78          stundenwerte_RR_00078_20041101_20191231_hist.zip  .zip  384729
# 87          stundenwerte_RR_00087_20050201_20191231_hist.zip  .zip  379869
# 91          stundenwerte_RR_00091_20040901_20191231_hist.zip  .zip  394972
# 103         stundenwerte_RR_00103_20040701_20191231_hist.zip  .zip  402997
#
#            type
# station_id
# 3             -
# 20            -
# 44            -
# 53            -
# 71            -
# 73            -
# 78            -
# 87            -
# 91            -
# 103           -

# %% [markdown]
# ### Download the Station Description File

# %%
station_fname = df_ftpdir[df_ftpdir['name'].str.contains(station_desc_pattern)]["name"].values[0]
print(station_fname)

# ALternative
#station_fname2 = df_ftpdir[df_ftpdir["name"].str.match("^.*Beschreibung_Stationen.*txt$")]["name"].values[0]
#print(station_fname2)
# Out:
# RR_Stundenwerte_Beschreibung_Stationen.txt

# %%
print("grab file: " + station_fname + "\nfrom ftp dir: " + ftp_dir)
grabFile(ftp_dir + station_fname, local_station_dir + station_fname)
# Out:
# grab file: RR_Stundenwerte_Beschreibung_Stationen.txt
# from ftp dir: /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/

# %%
# extract column names. They are in German (de)
# We have to use codecs because of difficulties with character encoding (German Umlaute)
import codecs

def station_desc_txt_to_csv(txtfile, csvfile):
    file = codecs.open(txtfile,"r","utf-8")
    r = file.readline()
    file.close()
    colnames_de = r.split()
    colnames_de
    
    # German-English dictionary
    translate = \
    {'Stations_id':'station_id',
     'von_datum':'date_from',
     'bis_datum':'date_to',
     'Stationshoehe':'altitude',
     'geoBreite': 'latitude',
     'geoLaenge': 'longitude',
     'Stationsname':'name',
     'Bundesland':'state'}
    
    colnames_en = [translate[h] for h in colnames_de]
    
    # Skip the first two rows and set the column names.
    df = pd.read_fwf(txtfile,skiprows=2,names=colnames_en, parse_dates=["date_from","date_to"],index_col = 0)
    
    # write CSV file with field separator semicolon
    df.to_csv(csvfile, sep = ";")
    return(df)

# %%
basename = os.path.splitext(station_fname)[0]
df_stations = station_desc_txt_to_csv(local_station_dir + station_fname, local_station_dir + basename + ".csv")
df_stations.head()
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 3          1995-09-01 2011-04-01       202   50.7827     6.0941
# 20         2004-08-14 2021-02-16       432   48.9220     9.9129
# 44         2007-04-01 2021-02-16        44   52.9336     8.2370
# 53         2005-10-01 2021-02-16        60   52.5850    13.5634
# 71         2004-10-22 2020-01-01       759   48.2156     8.9784
#
#                                 name                state
# station_id
# 3                             Aachen  Nordrhein-Westfalen
# 20          Abtsgm�nd-Untergr�ningen    Baden-W�rttemberg
# 44                      Gro�enkneten        Niedersachsen
# 53                       Ahrensfelde          Brandenburg
# 71                   Albstadt-Badkap    Baden-W�rttemberg

# %% [markdown]
# ### Select Stations Located in NRW from Station Description Dataframe

# %%
# station_ids_selected = df_stations[df_stations['state'].str.contains("Nordrhein")].index
# station_ids_selected

# %%
# Create variable with TRUE if state is Nordrhein-Westfalen

# isNRW = df_stations['state'] == "Nordrhein-Westfalen"
isNRW = df_stations['state'].str.contains("Nordrhein")

# Create variable with TRUE if date_to is latest date (indicates operation up to now)
isOperational = df_stations['date_to'] == df_stations.date_to.max() 

#isBefore1950 = df_stations['date_from'] < '1950'
#dfNRW = df_stations[isNRW & isOperational & isBefore1950]

# select on both conditions

dfNRW = df_stations[isNRW & isOperational]

#print("Number of stations in NRW: \n", dfNRW.count())
dfNRW
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 216        2004-10-01 2021-02-16       298   51.1143     7.8807
# 389        2009-11-01 2021-02-16       436   51.0148     8.4318
# 390        2004-07-01 2021-02-16       610   50.9837     8.3683
# 554        1995-09-01 2021-02-16        23   51.8293     6.5365
# 603        1999-03-03 2021-02-16       147   50.7293     7.2040
# ...               ...        ...       ...       ...        ...
# 13671      2007-12-01 2021-02-16       221   50.9655     7.2753
# 13696      2007-12-01 2021-02-16        60   51.5966     7.4048
# 13700      2008-05-01 2021-02-16       205   51.3329     7.3411
# 13713      2007-11-01 2021-02-16       386   51.0899     7.6289
# 15000      2011-04-01 2021-02-16       231   50.7983     6.0244
#
#                                     name                state
# station_id
# 216              Attendorn-Neulisternohl  Nordrhein-Westfalen
# 389                Berleburg, Bad-Arfeld  Nordrhein-Westfalen
# 390               Berleburg, Bad-St�nzel  Nordrhein-Westfalen
# 554         Bocholt-Liedern (Wasserwerk)  Nordrhein-Westfalen
# 603               K�nigswinter-Heiderhof  Nordrhein-Westfalen
# ...                                  ...                  ...
# 13671                       Overath-B�ke  Nordrhein-Westfalen
# 13696                  Waltrop-Abdinghof  Nordrhein-Westfalen
# 13700             Gevelsberg-Oberbr�king  Nordrhein-Westfalen
# 13713            Meinerzhagen-Redlendorf  Nordrhein-Westfalen
# 15000                     Aachen-Orsbach  Nordrhein-Westfalen
#
# [82 rows x 7 columns]

# %% [markdown]
# ## Geopandas - Create a Geo Data Frame
#
# A Geopandas geo data frame is a Pandas data frame enriched with an additional geometry column. Each row in the data frame becomes a location information. Thus a geo-df contains geometry and attributes, i.e. full features. The geo-df is self-contained and complete. It can be easily saved in different vectore file formats, i.e. shapefile or geopackage.

# %%
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import fiona
from pyproj import CRS

#df = pd.read_csv('data.csv')
df = dfNRW

geometry = [Point(xy) for xy in zip(df.longitude, df.latitude)]
crs = CRS("epsg:4326") #http://www.spatialreference.org/ref/epsg/2263/
stations_gdf = GeoDataFrame(df, crs=crs, geometry=geometry)

stations_gdf.head(5)
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 216        2004-10-01 2021-02-16       298   51.1143     7.8807
# 389        2009-11-01 2021-02-16       436   51.0148     8.4318
# 390        2004-07-01 2021-02-16       610   50.9837     8.3683
# 554        1995-09-01 2021-02-16        23   51.8293     6.5365
# 603        1999-03-03 2021-02-16       147   50.7293     7.2040
#
#                                     name                state  \
# station_id
# 216              Attendorn-Neulisternohl  Nordrhein-Westfalen
# 389                Berleburg, Bad-Arfeld  Nordrhein-Westfalen
# 390               Berleburg, Bad-St�nzel  Nordrhein-Westfalen
# 554         Bocholt-Liedern (Wasserwerk)  Nordrhein-Westfalen
# 603               K�nigswinter-Heiderhof  Nordrhein-Westfalen
#
#                             geometry
# station_id
# 216         POINT (7.88070 51.11430)
# 389         POINT (8.43180 51.01480)
# 390         POINT (8.36830 50.98370)
# 554         POINT (6.53650 51.82930)
# 603         POINT (7.20400 50.72930)

# %% [markdown]
# ## Connect to the PostGIS database

# %%
# PostgreSQL connection parameters -> create connection string (URL) 

param_dic = {
  "user" : "vivek",
  "pw"   : "",
  "host" : "localhost",
  "db"   : "GeoDB"
}

# https://www.w3schools.com/python/ref_string_format.asp
template = "postgres://{user}:{pw}@{host}:5432/{db}"

db_connection_url = template.format(**param_dic)
print("Connection URL: ", db_connection_url)
# Out:
# Connection URL:  postgres://vivek:@localhost:5432/GeoDB

# %% [markdown]
# ## Write Geopandas Data Frame directly into PostGIS Database
#
# * https://geopandas.readthedocs.io/en/latest/docs/reference/api/geopandas.GeoDataFrame.to_postgis.html
# * https://docs.sqlalchemy.org/en/13/core/types.html
# * https://www.postgresqltutorial.com/postgresql-primary-key/
# * https://www.postgresql.org/docs/13/sql-altertable.html

# %%
# https://geopandas.readthedocs.io/en/latest/docs/reference/api/geopandas.GeoDataFrame.to_postgis.html
# https://docs.sqlalchemy.org/en/13/core/types.html

from sqlalchemy import create_engine
from sqlalchemy import Numeric, Float, Date, REAL

engine = create_engine(db_connection_url)

# Set data types in PG explicitly.
dtypes = {"station_id": Numeric(6,0), "altitude" : REAL, "date_from" : Date, "date_to" : Date, "longitude" : REAL, "latitude" : REAL}

stations_gdf.to_postgis(name="stations", schema="dwd", if_exists = "replace", index = "station_id", index_label=True, con=engine, dtype=dtypes)

#engine.execute('alter table dwd.stations add constraint my_awesome_pkey primary key (station_id)')
engine.execute('alter table dwd.stations add primary key (station_id)')

# %% [markdown]
# ### Download TS Data from FTP Server
#
# **Problem:** Not all stations listed in the station description file are associated with a time series (zip file)! The stations in the description file and the set of stations whoch are TS data provided for (zip files) do not match perfectly.

# %%
# Add the names of the actually downloaded zip files to this list. 
local_zip_list = []

station_ids_selected = list(dfNRW.index)

for station_id in station_ids_selected:
    try:
        fname = df_zips["name"][station_id]
        print("fname = ", fname)
        #print("ftp_dir = ", ftp_dir)
        #print("local_dir = ", local_ts_dir)
        grabFile(ftp_dir + fname, local_ts_dir + fname)
        local_zip_list.append(fname)
    except:
        print("WARNING: TS file for key %d not found in FTP directory." % station_id)
# Out:
# fname =  stundenwerte_RR_00216_20041001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00389_20091101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00390_20040701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00554_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00603_19990303_20191002_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00613_20041101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00617_20040601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00644_20050101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00796_20041101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00871_20050801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00902_20061001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00934_20041001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_00989_20050201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01024_20060801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01046_20041001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01078_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01241_20061201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01246_20150801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01300_20040601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01303_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01327_20040801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01590_20030701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01595_20121001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_01766_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02027_20060601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02110_20030105_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02254_20050601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02473_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02483_19951012_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02497_20040801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02629_20040701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02667_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02810_20061201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02947_20061001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02968_20081201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_02999_20040701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03028_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03031_20040701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03081_20071201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03098_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03215_20070601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03321_20050701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03339_20060901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03499_20060701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03540_20041101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03591_20040601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03795_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_03913_20040701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04063_20030701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04127_20050101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04150_20051201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04313_20040801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04368_20041001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04371_19950901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04400_20040801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04488_20060801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04741_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_04849_20050601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05064_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05360_20070701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05480_20030910_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05513_20050901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05619_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05699_20041101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05717_20060901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_05733_20050501_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_06197_20001013_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_06264_20040601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_06313_20041201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_06337_20040801_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_07106_20060901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_07330_20051001_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_07344_20060601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_07374_20060301_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_07378_20060701_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13669_20070901_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13670_20070601_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13671_20071201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13696_20071201_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13700_20080501_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_13713_20071101_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/
# fname =  stundenwerte_RR_15000_20110401_20191231_hist.zip
# ftp_dir =  /climate_environment/CDC/observations_germany/climate/hourly/precipitation/historical/
# local_dir =  data/generated/DWD/hourly/precipitation/historical/

# %%
from zipfile import ZipFile

# %%
# Filter to extract PRECIPITATION from recent and historical RR product files.

def prec_ts_to_df(fname):

    import pandas as pd
    import pytz
    from datetime import datetime
    
    dateparse = lambda dates: [datetime.strptime(str(d), '%Y%m%d%H') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse, na_values = [-999.0, -999])

    #df = pd.read_csv(fname, delimiter=";", encoding="iso8859_2",\
    #             index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse)
    
    # https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    
    # TIME ZONES: https://stackoverflow.com/questions/22800079/converting-time-zone-pandas-dataframe
    # DWD Prec Data is given in UTC
    
    df.index = df.index.tz_localize(pytz.utc)
    
    return(df)

# %%
csvfname = "prec_ts_appended_3_cols.csv"

first = False

for elt in local_zip_list:
    ffname = local_ts_dir + elt
    print("Zip archive: " + ffname)
    with ZipFile(ffname) as myzip:
        # read the time series data from the file starting with "produkt"
        prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
        print("Extract product file: %s" % prodfilename)
        print()
        with myzip.open(prodfilename) as myfile:
            dftmp = prec_ts_to_df(myfile)[["stations_id","r1"]]
            # df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)
            dftmp.rename(columns={'stations_id': 'station_id', 'r1': 'val', 'mess_datum': 'ts'}, inplace = True)
            dftmp.rename_axis('ts', inplace = True)
            # dftmp.to_csv(f, header=f.tell()==0)
            if (first):
                first = False
                dftmp.to_csv(csvfname, mode = "w", header = True)
            else:
                dftmp.to_csv(csvfname, mode = "a", header = False)
# Out:
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00216_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_00216.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00389_20091101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20091101_20191231_00389.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00390_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_00390.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00554_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_00554.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00603_19990303_20191002_hist.zip
# Extract product file: produkt_rr_stunde_19990303_20191002_00603.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00613_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_00613.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00617_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_00617.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00644_20050101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20191231_00644.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00796_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_00796.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00871_20050801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050801_20191231_00871.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00902_20061001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20191231_00902.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00934_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_00934.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_00989_20050201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050201_20191231_00989.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01024_20060801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20191231_01024.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01046_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_01046.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01078_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01078.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01241_20061201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20191231_01241.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01246_20150801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20150801_20191231_01246.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01300_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_01300.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01303_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01303.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01327_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_01327.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01590_20030701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20191231_01590.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01595_20121001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20121001_20191231_01595.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_01766_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01766.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02027_20060601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060601_20191231_02027.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02110_20030105_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030105_20191231_02110.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02254_20050601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20191231_02254.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02473_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_02473.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02483_19951012_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19951012_20191231_02483.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02497_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_02497.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02629_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_02629.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02667_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_02667.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02810_20061201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20191231_02810.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02947_20061001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20191231_02947.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02968_20081201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20081201_20191231_02968.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_02999_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_02999.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03028_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_03028.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03031_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_03031.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03081_20071201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20191231_03081.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03098_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_03098.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03215_20070601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070601_20191231_03215.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03321_20050701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050701_20191231_03321.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03339_20060901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20191231_03339.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03499_20060701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20191231_03499.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03540_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_03540.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03591_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_03591.txt
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03795_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_03795.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_03913_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_03913.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04063_20030701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20191231_04063.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04127_20050101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20191231_04127.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04150_20051201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20051201_20191231_04150.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04313_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_04313.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04368_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_04368.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04371_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_04371.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04400_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_04400.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04488_20060801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20191231_04488.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04741_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_04741.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_04849_20050601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20191231_04849.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05064_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_05064.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05360_20070701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070701_20191231_05360.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05480_20030910_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030910_20191231_05480.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05513_20050901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050901_20191231_05513.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05619_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_05619.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05699_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_05699.txt
#
# Zip archive: data/generated/DWD/hourly/precipitation/historical/stundenwerte_RR_05717_20060901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20191231_05717.txt

# %%
dftmp

# %%
first = True

dtypes = {"station_id": Numeric(6,0), "val" : REAL}

#for elt in local_zip_list[0:1]:
for elt in local_zip_list:
    ffname = local_ts_dir + elt
    #print("Zip archive: " + ffname)
    with ZipFile(ffname) as myzip:
        # read the time series data from the file starting with "produkt"
        prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
        print("Extract product file: %s" % prodfilename)
        # print()
        with myzip.open(prodfilename) as myfile:
            dftmp = prec_ts_to_df(myfile)[["stations_id","r1"]]
            # df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)
            dftmp.rename(columns={'stations_id': 'station_id', 'r1': 'val', 'mess_datum': 'ts'}, inplace = True)
            dftmp.rename_axis('ts', inplace = True)
            # dftmp.to_csv(f, header=f.tell()==0)
            if (first):
                first = False
                # dftmp.to_csv(csvfname, mode = "w", header = False)
                dftmp.to_sql(name="prec", schema="dwd", if_exists = "replace", index = ["ts"], index_label=True, con=engine, dtype=dtypes)
            else:
                # dftmp.to_csv(csvfname, mode = "a", header = False)
                dftmp.to_sql(name="prec", schema="dwd", if_exists = "append",  index = ["ts"], index_label=True, con=engine, dtype=dtypes)

# After insert completed: ceate index
print("create index")
engine.execute("ALTER TABLE dwd.prec ADD PRIMARY KEY (ts, station_id)")

# %% [markdown]
# # HOMEWORK: Create a Map in QGIS!
#
# The **pdf file in the notebook folder** shows the final result you have to produce yourself.
#
# Follow the tutorial http://www.qgistutorials.com/en/docs/3/making_a_map.html
#
# In class we created a vector data layer (point shape file) with the coordinates of the DWD CDC climate stations from a CSV file we generated from the meta data file downloaded from the open data DWD FTP archive (hourly values, precipitation).
#
# Create a map of the DWD climate stations located in NRW. Use a shapefile of the NRW administrative boundaries.
#
# Use the EPSG:28532 coordinate reference system (projection). We will learn later what it is.
#
#
# The borders of the federal state NRW can be found in a zip archieve containing the official administrative boundaries of NRW.
#
# Download the archieve **dvg1_EPSG25832_Shape.zip** from here: https://www.opengeodata.nrw.de/produkte/geobasis/vkg/dvg/dvg1/ and add the right shape file (.shp) as a vector layer to your QGIS project.
