# %% [markdown]
# # Read DWD CDC Time Series, Merge with Station Description and Append
#
# The main idea behind this activity is to reformat and merge time series (here we use hourly precipitation) from the DWD Climate Data Center in such a way that it can be used with the **QGIS time manager extension**.
#
# This extension allows to filter an attribute table of a vector layer (e.g. points representing precipitation stations plus precipitation data) with a time stamp column. The extension limits the attribute table to the records matching the particular time stamp provided by the time manager extension (e.g. by the user moving the time slider). This selected subset of the attribute table is then used to change the sympology of the vector layer according to the variable of interest (e.g. precipitation rate).
#
# The QGIS time manager extension approach is a bit brute force, because each individual measurement at a station at a given time is one feature (row in the table), i.e. a time series at station X with hourly resolution for a day (24 values) entails 24 different features with the same station id and the corresponding coordinates but different times. As of now this 1:n relationship can only be realized by importing a CSV file with the according structure.
#
# (At least I was not able to generate the required view on a 1:n relationship by merging a point vector layer with precipitation station locations and an imported CSV time series table.)
#
# The final data format is a concatenation of time series together with geographic location in 2D (e.g. lat, lon). The required data format looks principly like this:
#
#
# | station_id |        name        |   lat   |   lon  |        meas_time       | prec_rate |
# |:----------:|:------------------:|:-------:|:------:|:----------------------:|:---------:|
# |        ... | ...                |     ... |    ... |                    ... |       ... |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T08:00:00UTC |       1.5 |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T09:00:00UTC |       1.7 |
# |       1595 | Gelsenkirchen-Buer | 51.5762 | 7.0652 | 2018-12-07T10:00:00UTC |       0.1 |
# |        ... | ...                |     ... |    ... |                    ... |       ... |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T08:00:00UTC |       0.8 |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T09:00:00UTC |       0.4 |
# |      13670 | Duisburg-Baerl     | 51.5088 | 6.7018 | 2018-12-07T10:00:00UTC |       0.0 |
# |        ... | ...                |     ... |    ... |                    ... |       ... |
#
#
# (Table generated with https://www.tablesgenerator.com/markdown_tables)
#
# To achieve this the precipitation time series (station_id, meas_time, prec_rate) have to be merged with the station metadata (station_id, lat, lon) coming from the a CSV file generated in an earlier activity. We use Pandas to read, join and append the data to generate the final CSV file to be imported as a point layer to QGIS.
#
# This final data format is far from being optimal because of large size and highly redundant information. This is a challenge for QGIS which loses responsiveness with large data. To jsut show the principle it is advisable to limit to size of the problem.
#
# The following filters (selection criteria) are applied:
#
#   * Precipitation stations in NRW only (approx. 127 stations)
#   * Hourly precipitation data
#   * Time interval from 2018-12-01 to last date in precipitation data set
#
# Still: 40 days * 24 hrs / day * 127 stations = 121920 records leading to 121920 features in a point layer in QGIS.
#
# In fact, the resulting number of records is arround 91000. The reason might be that not all stations in the station list have time series. This has to be checked carefully.

# %% [markdown]
# ## FTP Connection

# %% [markdown]
# ### Connection Parameters

# %%
server = "opendata.dwd.de"
user   = "anonymous"
passwd = ""

# %% [markdown]
# ### FTP Directory Definition and Station Description Filename Pattern

# %%
# The topic of interest.
topic_dir = "/hourly/precipitation/historical/"
#topic_dir = "/annual/kl/historical/"

# This is the search pattern common to ALL station description file names 
station_desc_pattern = "_Beschreibung_Stationen.txt"

# Below this directory tree node all climate data are stored.
ftp_climate_data_dir = "/climate_environment/CDC/observations_germany/climate/"
ftp_dir =  ftp_climate_data_dir + topic_dir

# %% [markdown]
# ### Local Directories

# %%
local_ftp_dir         = "../data/original/DWD/"      # Local directory to store local ftp data copies, the local data source or input data. 
local_ftp_station_dir = local_ftp_dir + topic_dir # Local directory where local station info is located
local_ftp_ts_dir      = local_ftp_dir + topic_dir # Local directory where time series downloaded from ftp are located

local_generated_dir   = "../data/generated/DWD/" # The generated of derived data in contrast to local_ftp_dir
local_station_dir     = local_generated_dir + topic_dir # Derived station data, i.e. the CSV file
local_ts_merged_dir   = local_generated_dir + topic_dir # Parallelly merged time series, wide data frame with one TS per column
local_ts_appended_dir = local_generated_dir + topic_dir # Serially appended time series, long data frame for QGIS TimeManager Plugin

# %%
print(local_ftp_dir)
print(local_ftp_station_dir)
print(local_ftp_ts_dir)
print()
print(local_generated_dir)
print(local_station_dir)
print(local_ts_merged_dir)
print(local_ts_appended_dir)
# Out:
# ../data/original/DWD/
# ../data/original/DWD//hourly/precipitation/historical/
# ../data/original/DWD//hourly/precipitation/historical/
#
# ../data/generated/DWD/
# ../data/generated/DWD//hourly/precipitation/historical/
# ../data/generated/DWD//hourly/precipitation/historical/
# ../data/generated/DWD//hourly/precipitation/historical/

# %%
import os
os.makedirs(local_ftp_dir,exist_ok = True) # it does not complain if the dir already exists.
os.makedirs(local_ftp_station_dir,exist_ok = True)
os.makedirs(local_ftp_ts_dir,exist_ok = True)

os.makedirs(local_generated_dir,exist_ok = True)
os.makedirs(local_station_dir,exist_ok = True)
os.makedirs(local_ts_merged_dir,exist_ok = True)
os.makedirs(local_ts_appended_dir,exist_ok = True)

# %% [markdown]
# ### FTP Connect

# %%
import ftplib
ftp = ftplib.FTP(server)
res = ftp.login(user=user, passwd = passwd)
print(res)
# Out:
# 230 Login successful.

# %%
ret = ftp.cwd(".")

# %%
#ftp.quit()

# %% [markdown]
# ### FTP Grab File Function

# %%
def grabFile(ftpfullname,localfullname):
    try:
        ret = ftp.cwd(".") # A dummy action to check the connection and to provoke an exception if necessary.
        localfile = open(localfullname, 'wb')
        ftp.retrbinary('RETR ' + ftpfullname, localfile.write, 1024)
        localfile.close()
    
    except ftplib.error_perm:
        print("FTP ERROR. Operation not permitted. File not found?")

    except ftplib.error_temp:
        print("FTP ERROR. Timeout.")

    except ConnectionAbortedError:
        print("FTP ERROR. Connection aborted.")

# %% [markdown]
# ### Generate Pandas Dataframe from FTP Directory Listing

# %%
import pandas as pd
import os

def gen_df_from_ftp_dir_listing(ftp, ftpdir):
    lines = []
    flist = []
    try:    
        res = ftp.retrlines("LIST "+ftpdir, lines.append)
    except:
        print("Error: ftp.retrlines() failed. ftp timeout? Reconnect!")
        return
        
    if len(lines) == 0:
        print("Error: ftp dir is empty")
        return
    
    for line in lines:
#        print(line)
        [ftype, fsize, fname] = [line[0:1], int(line[31:42]), line[56:]]
#        itemlist = [line[0:1], int(line[31:42]), line[56:]]
#        flist.append(itemlist)
        
        fext = os.path.splitext(fname)[-1]
        
        if fext == ".zip":
            station_id = int(fname.split("_")[2])
        else:
            station_id = -1 
        
        flist.append([station_id, fname, fext, fsize, ftype])
        
        

    df_ftpdir = pd.DataFrame(flist,columns=["station_id", "name", "ext", "size", "type"])
    return(df_ftpdir)

# %%
df_ftpdir = gen_df_from_ftp_dir_listing(ftp, ftp_dir)

# %%
df_ftpdir.head(10)
# Out:
#    station_id                                               name   ext  \
# 0          -1  BESCHREIBUNG_obsgermany_climate_hourly_precipi...  .pdf
# 1          -1  DESCRIPTION_obsgermany_climate_hourly_precipit...  .pdf
# 2          -1         RR_Stundenwerte_Beschreibung_Stationen.txt  .txt
# 3           3   stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip
# 4          20   stundenwerte_RR_00020_20040814_20191231_hist.zip  .zip
# 5          44   stundenwerte_RR_00044_20070401_20191231_hist.zip  .zip
# 6          53   stundenwerte_RR_00053_20051001_20191231_hist.zip  .zip
# 7          71   stundenwerte_RR_00071_20041022_20191231_hist.zip  .zip
# 8          73   stundenwerte_RR_00073_20070401_20191231_hist.zip  .zip
# 9          78   stundenwerte_RR_00078_20041101_20191231_hist.zip  .zip
#
#      size type
# 0   71445    -
# 1   69716    -
# 2  209079    -
# 3  419265    -
# 4  407378    -
# 5  320516    -
# 6  361931    -
# 7  402880    -
# 8  333070    -
# 9  384729    -

# %% [markdown]
# ### Dataframe with TS Zip Files

# %%
#df_ftpdir["ext"]==".zip"
df_zips = df_ftpdir[df_ftpdir["ext"]==".zip"]
df_zips.set_index("station_id", inplace = True)
df_zips.head(10)
# Out:
#                                                         name   ext    size  \
# station_id
# 3           stundenwerte_RR_00003_19950901_20110401_hist.zip  .zip  419265
# 20          stundenwerte_RR_00020_20040814_20191231_hist.zip  .zip  407378
# 44          stundenwerte_RR_00044_20070401_20191231_hist.zip  .zip  320516
# 53          stundenwerte_RR_00053_20051001_20191231_hist.zip  .zip  361931
# 71          stundenwerte_RR_00071_20041022_20191231_hist.zip  .zip  402880
# 73          stundenwerte_RR_00073_20070401_20191231_hist.zip  .zip  333070
# 78          stundenwerte_RR_00078_20041101_20191231_hist.zip  .zip  384729
# 87          stundenwerte_RR_00087_20050201_20191231_hist.zip  .zip  379869
# 91          stundenwerte_RR_00091_20040901_20191231_hist.zip  .zip  394972
# 103         stundenwerte_RR_00103_20040701_20191231_hist.zip  .zip  402997
#
#            type
# station_id
# 3             -
# 20            -
# 44            -
# 53            -
# 71            -
# 73            -
# 78            -
# 87            -
# 91            -
# 103           -

# %% [markdown]
# ### Download the Station Description File

# %%
station_fname = df_ftpdir[df_ftpdir['name'].str.contains(station_desc_pattern)]["name"].values[0]
print(station_fname)

# ALternative
#station_fname2 = df_ftpdir[df_ftpdir["name"].str.match("^.*Beschreibung_Stationen.*txt$")]["name"].values[0]
#print(station_fname2)
# Out:
# RR_Stundenwerte_Beschreibung_Stationen.txt

# %%
print("grabFile: ")
print("From: " + ftp_dir + station_fname)
print("To:   " + local_ftp_station_dir + station_fname)
grabFile(ftp_dir + station_fname, local_ftp_station_dir + station_fname)
# Out:
# grabFile:
# From: /climate_environment/CDC/observations_germany/climate//hourly/precipitation/historical/RR_Stundenwerte_Beschreibung_Stationen.txt
# To:   ../data/original/DWD//hourly/precipitation/historical/RR_Stundenwerte_Beschreibung_Stationen.txt

# %%
# extract column names. They are in German (de)
# We have to use codecs because of difficulties with character encoding (German Umlaute)
import codecs

def station_desc_txt_to_csv(txtfile, csvfile):
    file = codecs.open(txtfile,"r","utf-8")
    r = file.readline()
    file.close()
    colnames_de = r.split()
    colnames_de
    
    translate = \
    {'Stations_id':'station_id',
     'von_datum':'date_from',
     'bis_datum':'date_to',
     'Stationshoehe':'altitude',
     'geoBreite': 'latitude',
     'geoLaenge': 'longitude',
     'Stationsname':'name',
     'Bundesland':'state'}
    
    colnames_en = [translate[h] for h in colnames_de]
    
    # Skip the first two rows and set the column names.
    df = pd.read_fwf(txtfile,skiprows=2,names=colnames_en, parse_dates=["date_from","date_to"],index_col = 0)
    
    # write csv
    df.to_csv(csvfile, sep = ";")
    return(df)

# %%
basename = os.path.splitext(station_fname)[0]
df_stations = station_desc_txt_to_csv(local_ftp_station_dir + station_fname, local_station_dir + basename + ".csv")
df_stations.head()
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 3          1995-09-01 2011-04-01       202   50.7827     6.0941
# 20         2004-08-14 2021-02-24       432   48.9220     9.9129
# 44         2007-04-01 2021-02-24        44   52.9336     8.2370
# 53         2005-10-01 2021-02-24        60   52.5850    13.5634
# 71         2004-10-22 2020-01-01       759   48.2156     8.9784
#
#                                 name                state
# station_id
# 3                             Aachen  Nordrhein-Westfalen
# 20          Abtsgmünd-Untergröningen    Baden-Württemberg
# 44                      Großenkneten        Niedersachsen
# 53                       Ahrensfelde          Brandenburg
# 71                   Albstadt-Badkap    Baden-Württemberg

# %% [markdown]
# ### Select Stations Located in NRW from Station Description Dataframe

# %%
station_ids_selected = df_stations[df_stations['state'].str.contains("Nordrhein")].index
station_ids_selected
# Out:
# Int64Index([    3,   216,   326,   389,   390,   554,   555,   599,   603,
#               613,   617,   644,   796,   871,   902,   934,   989,  1024,
#              1046,  1078,  1241,  1246,  1300,  1303,  1327,  1590,  1595,
#              1766,  2027,  2110,  2254,  2473,  2483,  2497,  2629,  2667,
#              2703,  2810,  2947,  2968,  2999,  3028,  3031,  3081,  3098,
#              3215,  3321,  3339,  3499,  3540,  3591,  3795,  3913,  4063,
#              4127,  4150,  4154,  4313,  4368,  4371,  4400,  4488,  4692,
#              4741,  4849,  5064,  5347,  5360,  5468,  5480,  5513,  5619,
#              5699,  5717,  5719,  5733,  6197,  6264,  6276,  6313,  6337,
#              7106,  7330,  7344,  7374,  7378, 13669, 13670, 13671, 13696,
#             13700, 13713, 15000],
#            dtype='int64', name='station_id')

# %%
# Create variable with TRUE if state is Nordrhein-Westfalen

# isNRW = df_stations['state'] == "Nordrhein-Westfalen"
isNRW = df_stations['state'].str.contains("Nordrhein")

# Create variable with TRUE if date_to is latest date (indicates operation up to now)
isOperational = df_stations['date_to'] >= '2017'

#isBefore1950 = df_stations['date_from'] < '1950'
#dfNRW = df_stations[isNRW & isOperational & isBefore1950]

# select on both conditions

dfNRW = df_stations[isNRW & isOperational]

#print("Number of stations in NRW: \n", dfNRW.count())
dfNRW
# Out:
#             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 216        2004-10-01 2021-02-24       298   51.1143     7.8807
# 389        2009-11-01 2021-02-24       436   51.0148     8.4318
# 390        2004-07-01 2021-02-24       610   50.9837     8.3683
# 554        1995-09-01 2021-02-24        23   51.8293     6.5365
# 555        2008-01-01 2018-11-01       101   51.4789     7.2697
# 603        1999-03-03 2021-02-24       147   50.7293     7.2040
# 613        2004-11-01 2021-02-24       206   51.5677     9.2324
# 617        2004-06-01 2021-02-24        47   51.8730     6.8863
# 644        2005-01-01 2021-02-24       150   51.7049     9.1738
# 796        2004-11-01 2021-02-24       412   50.7556     8.1257
# 871        2005-08-01 2021-02-24        87   51.9618     7.1585
# 902        2006-10-01 2021-02-24       573   50.4115     6.5615
# 934        2004-10-01 2021-02-24        88   51.7835     8.5658
# 989        2005-02-01 2021-02-24        46   51.5765     6.7849
# 1024       2006-08-01 2021-02-24        37   51.1157     6.8510
# 1046       2004-10-01 2021-02-24        72   51.7585     7.7528
# 1078       1995-09-01 2021-02-24        37   51.2960     6.7686
# 1241       2006-12-01 2021-02-24       128   52.1500     8.5226
# 1246       2015-08-01 2021-02-24       104   51.8418     8.0607
# 1300       2004-06-01 2021-02-24       351   51.2540     8.1565
# 1303       1995-09-01 2021-02-24       150   51.4041     6.9677
# 1327       2004-08-01 2021-02-24       147   50.7119     6.7905
# 1590       2003-07-01 2021-02-24        37   51.4942     6.2463
# 1595       2012-10-01 2021-02-24        91   51.5762     7.0652
# 1766       1995-09-01 2021-02-24        48   52.1344     7.6969
# 2027       2006-06-01 2021-02-24        63   51.9753     8.2094
# 2110       2003-01-05 2021-02-24        57   51.0411     6.1042
# 2254       2005-06-01 2021-02-24        46   52.2396     7.6449
# 2473       2004-12-01 2021-02-24        76   50.9316     6.3431
# 2483       1995-10-12 2021-02-24       839   51.1803     8.4891
# ...               ...        ...       ...       ...        ...
# 4692       2008-03-01 2018-12-01       229   50.8534     7.9966
# 4741       2004-12-01 2021-02-24       152   51.1400     7.0930
# 4849       2005-06-01 2021-02-24        64   52.1173     7.3411
# 5064       2004-12-01 2021-02-24        37   51.2897     6.4437
# 5347       1995-09-01 2021-02-24       236   51.5039     9.1118
# 5360       2007-07-01 2021-02-24       331   51.4319     8.2665
# 5468       2006-07-01 2020-10-01       418   50.9377     7.8475
# 5480       2003-09-10 2021-02-24        85   51.5763     7.8879
# 5513       2005-09-01 2021-02-24        92   52.2902     7.8687
# 5619       2004-12-01 2021-02-24       360   51.1637     7.4234
# 5699       2004-11-01 2021-02-24       312   51.5427     8.7784
# 5717       2006-09-01 2021-02-24       134   51.2256     7.1052
# 154         stundenwerte_RR_00154_20050301_20191231_hist.zip  .zip  389656
# 158         stundenwerte_RR_00158_20040701_20191231_hist.zip  .zip  402879
# 161         stundenwerte_RR_00161_20110901_20191231_hist.zip  .zip  218166
# 164         stundenwerte_RR_00164_19950901_20191231_hist.zip  .zip  646783
# 167         stundenwerte_RR_00167_20040901_20191231_hist.zip  .zip  389908
# 183         stundenwerte_RR_00183_19950901_20191231_hist.zip  .zip  693601
# 191         stundenwerte_RR_00191_20050301_20191231_hist.zip  .zip  386612
# 194         stundenwerte_RR_00194_20050201_20191231_hist.zip  .zip  383276
# 198         stundenwerte_RR_00198_19950901_20191231_hist.zip  .zip  677952
# 200         stundenwerte_RR_00200_20041201_20191231_hist.zip  .zip  404692
# 205         stundenwerte_RR_00205_20050501_20191231_hist.zip  .zip  405546
# 211         stundenwerte_RR_00211_20041101_20191231_hist.zip  .zip  747001
# ...                                                      ...   ...     ...
# 13671       stundenwerte_RR_13671_20071201_20191231_hist.zip  .zip  323400
# 13672       stundenwerte_RR_13672_20080501_20150101_hist.zip  .zip  186416
# 13674       stundenwerte_RR_13674_20070801_20191231_hist.zip  .zip  336733
# 13675       stundenwerte_RR_13675_20071101_20191231_hist.zip  .zip  300527
# 13687       stundenwerte_RR_13687_20071101_20191231_hist.zip  .zip  316947
# 13688       stundenwerte_RR_13688_20080301_20191231_hist.zip  .zip  305597
# 13696       stundenwerte_RR_13696_20071201_20191231_hist.zip  .zip  317829
# 13698       stundenwerte_RR_13698_20080101_20191231_hist.zip  .zip  313643
# 13699       stundenwerte_RR_13699_20080301_20191231_hist.zip  .zip  296427
# 13700       stundenwerte_RR_13700_20080501_20191231_hist.zip  .zip  308450
# 13710       stundenwerte_RR_13710_20080401_20191231_hist.zip  .zip  305465
# 13711       stundenwerte_RR_13711_20071201_20191231_hist.zip  .zip  307547
# 13712       stundenwerte_RR_13712_20080901_20191231_hist.zip  .zip  292522
# 13713       stundenwerte_RR_13713_20071101_20191231_hist.zip  .zip  332967
# 13715       stundenwerte_RR_13715_20080301_20191231_hist.zip  .zip  306823
# 13716       stundenwerte_RR_13716_20080901_20191231_hist.zip  .zip  293484
# 13774       stundenwerte_RR_13774_20080601_20191231_hist.zip  .zip  301867
# 13776       stundenwerte_RR_13776_20080301_20110104_hist.zip  .zip   74286
# 13777       stundenwerte_RR_13777_20080601_20191231_hist.zip  .zip  286800
# 13965       stundenwerte_RR_13965_20081201_20191231_hist.zip  .zip  291099
# 14157       stundenwerte_RR_14157_20091201_20191231_hist.zip  .zip  260340
# 15000       stundenwerte_RR_15000_20110401_20191231_hist.zip  .zip  252079
# 15003       stundenwerte_RR_15003_20110501_20191231_hist.zip  .zip  216509
# 15207       stundenwerte_RR_15207_20131101_20191231_hist.zip  .zip  166610
# 15444       stundenwerte_RR_15444_20140901_20191231_hist.zip  .zip  144713
# 15478       stundenwerte_RR_15478_20150201_20191231_hist.zip  .zip  126658
# 15490       stundenwerte_RR_15490_20161201_20191231_hist.zip  .zip   81166
# 15512       stundenwerte_RR_15512_20160901_20191231_hist.zip  .zip   83934
# 15514       stundenwerte_RR_15514_20171101_20191231_hist.zip  .zip   56846
# 15555       stundenwerte_RR_15555_20160501_20191231_hist.zip  .zip   95314
#
#            type
# station_id
# 3             -
# 20            -
# 44            -
# 53            -
# 71            -
# 73            -
# 78            -
# 87            -
# 91            -
# 103           -
# 118           -
# 124           -
# 130           -
# 131           -
# 142           -
# 150           -
# 151           -
# 152           -
# 154           -
# 158           -
# 161           -
# 164           -
# 167           -
# 183           -
# 191           -
# 194           -
# 198           -
# 200           -
# 205           -
# 211           -
# ...         ...
# 13671         -
# 13672         -
# 13674         -
# 13675         -
# 13687         -
# 13688         -
# 13696         -
# 13698         -
# 13699         -
# 13700         -
# 13710         -
# 13711         -
# 13712         -
# 13713         -
# 13715         -
# 13716         -
# 13774         -
# 13776         -
# 13777         -
# 13965         -
# 14157         -
# 15000         -
# 15003         -
# 15207         -
# 15444         -
# 15478         -
# 15490         -
# 15512         -
# 15514         -
# 15555         -
#
# [1035 rows x 4 columns]

# %% [markdown]
# ### Download TS Data from FTP Server
#
# Problem: Not all stations listed in the station description file are associated with a time series (zip file)! The stations in the description file and the set of stations whoch are TS data provided for (zip files) do not match perfectly.

# %%
list(dfNRW.index)
dfNRW.count
# Out:
# <bound method DataFrame.count of             date_from    date_to  altitude  latitude  longitude  \
# station_id
# 216        2004-10-01 2021-02-24       298   51.1143     7.8807
# 389        2009-11-01 2021-02-24       436   51.0148     8.4318
# 390        2004-07-01 2021-02-24       610   50.9837     8.3683
# 554        1995-09-01 2021-02-24        23   51.8293     6.5365
# 555        2008-01-01 2018-11-01       101   51.4789     7.2697
# 603        1999-03-03 2021-02-24       147   50.7293     7.2040
# 613        2004-11-01 2021-02-24       206   51.5677     9.2324
# 617        2004-06-01 2021-02-24        47   51.8730     6.8863
# 644        2005-01-01 2021-02-24       150   51.7049     9.1738
# 796        2004-11-01 2021-02-24       412   50.7556     8.1257
# 871        2005-08-01 2021-02-24        87   51.9618     7.1585
# 902        2006-10-01 2021-02-24       573   50.4115     6.5615
# 934        2004-10-01 2021-02-24        88   51.7835     8.5658
# 989        2005-02-01 2021-02-24        46   51.5765     6.7849
# 1024       2006-08-01 2021-02-24        37   51.1157     6.8510
# 1046       2004-10-01 2021-02-24        72   51.7585     7.7528
# 1078       1995-09-01 2021-02-24        37   51.2960     6.7686
# 1241       2006-12-01 2021-02-24       128   52.1500     8.5226
# 1246       2015-08-01 2021-02-24       104   51.8418     8.0607
# 1300       2004-06-01 2021-02-24       351   51.2540     8.1565
# 1303       1995-09-01 2021-02-24       150   51.4041     6.9677
# 1327       2004-08-01 2021-02-24       147   50.7119     6.7905
# 1590       2003-07-01 2021-02-24        37   51.4942     6.2463
# 1595       2012-10-01 2021-02-24        91   51.5762     7.0652
# 1766       1995-09-01 2021-02-24        48   52.1344     7.6969
# 2027       2006-06-01 2021-02-24        63   51.9753     8.2094
# 2110       2003-01-05 2021-02-24        57   51.0411     6.1042
# 2254       2005-06-01 2021-02-24        46   52.2396     7.6449
# stundenwerte_RR_04488_20060801_20191231_hist.zip
# stundenwerte_RR_04692_20080301_20181201_hist.zip
# stundenwerte_RR_04741_20041201_20191231_hist.zip
# stundenwerte_RR_04849_20050601_20191231_hist.zip
# stundenwerte_RR_05064_20041201_20191231_hist.zip
# stundenwerte_RR_05347_19950901_20191231_hist.zip
# stundenwerte_RR_05360_20070701_20191231_hist.zip
# stundenwerte_RR_05468_20060701_20191231_hist.zip
# stundenwerte_RR_05480_20030910_20191231_hist.zip
# stundenwerte_RR_05513_20050901_20191231_hist.zip
# stundenwerte_RR_05619_20041201_20191231_hist.zip
# stundenwerte_RR_05699_20041101_20191231_hist.zip
# stundenwerte_RR_05717_20060901_20191231_hist.zip
# stundenwerte_RR_05733_20050501_20191231_hist.zip
# stundenwerte_RR_06197_20001013_20191231_hist.zip
# stundenwerte_RR_06264_20040601_20191231_hist.zip
# stundenwerte_RR_06276_20041101_20191102_hist.zip
# stundenwerte_RR_06313_20041201_20191231_hist.zip
# stundenwerte_RR_06337_20040801_20191231_hist.zip
# stundenwerte_RR_07106_20060901_20191231_hist.zip
# stundenwerte_RR_07330_20051001_20191231_hist.zip
# stundenwerte_RR_07344_20060601_20191231_hist.zip
# stundenwerte_RR_07374_20060301_20191231_hist.zip
# stundenwerte_RR_07378_20060701_20191231_hist.zip
# stundenwerte_RR_13669_20070901_20191231_hist.zip
# stundenwerte_RR_13670_20070601_20191231_hist.zip
# stundenwerte_RR_13671_20071201_20191231_hist.zip
# stundenwerte_RR_13696_20071201_20191231_hist.zip
# stundenwerte_RR_13700_20080501_20191231_hist.zip
# stundenwerte_RR_13713_20071101_20191231_hist.zip
# stundenwerte_RR_15000_20110401_20191231_hist.zip

# %% [markdown]
# ### Join (Merge) the Time Series Columns
#
# https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

# %%
from datetime import datetime

def prec_ts_to_df(fname):
    
    dateparse = lambda dates: [datetime.strptime(str(d), '%Y%m%d%H') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse, na_values = [-999.0, -999])

    #df = pd.read_csv(fname, delimiter=";", encoding="iso8859_2",\
    #             index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse)
    
    # https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    return(df)

# %%
from datetime import datetime

def temp_ts_to_df(fname):
    
    dateparse = lambda dates: [datetime.strptime(str(d), '%Y%m%d') for d in dates]

    df = pd.read_csv(fname, delimiter=";", encoding="utf8", index_col="MESS_DATUM_BEGINN", parse_dates = ["MESS_DATUM_BEGINN"], date_parser = dateparse, na_values = [-999.0, -999])

    #df = pd.read_csv(fname, delimiter=";", encoding="iso8859_2",\
    #             index_col="MESS_DATUM", parse_dates = ["MESS_DATUM"], date_parser = dateparse)
    
    # https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd

    # Column headers: remove leading blanks (strip), replace " " with "_", and convert to lower case.
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    df.index.name = df.index.name.strip().lower().replace(' ', '_').replace('(', '').replace(')', '')
    return(df)

# %%
from zipfile import ZipFile

# %%
# PRECIPITATION
def prec_ts_merge():
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_list:
        ffname = local_ftp_ts_dir + elt
        print("Zip archive: " + ffname)
        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
            print("Extract product file: %s" % prodfilename)
            print()
            with myzip.open(prodfilename) as myfile:
                dftmp = prec_ts_to_df(myfile)
                s = dftmp["r1"].rename(dftmp["stations_id"][0]).to_frame()
                # outer merge.
                df = pd.merge(df, s, left_index=True, right_index=True, how='outer')

    #df.index.names = ["year"]
    df.index.rename(name = "time", inplace = True)
    return(df)

# %%
# TEMPERATURE
def temp_ts_merge():
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_list:
        ffname = local_ftp_ts_dir + elt
        print("Zip archive: " + ffname)
        with ZipFile(ffname) as myzip:
            # read the time series data from the file starting with "produkt"
            prodfilename = [elt for elt in myzip.namelist() if elt.split("_")[0]=="produkt"][0] 
            print("Extract product file: %s" % prodfilename)
            print()
            with myzip.open(prodfilename) as myfile:
                dftmp = temp_ts_to_df(myfile)
                s = dftmp["ja_tt"].rename(dftmp["stations_id"][0]).to_frame()
                # outer merge.
                df = pd.merge(df, s, left_index=True, right_index=True, how='outer')

    #df.index.names = ["year"]
    df.index.rename(name = "time", inplace = True)
    return(df)

# %%
df_merged_ts = prec_ts_merge()
# Out:
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00216_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_00216.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00389_20091101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20091101_20191231_00389.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00390_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_00390.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00554_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_00554.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00555_20080101_20181101_hist.zip
# Extract product file: produkt_rr_stunde_20080101_20181101_00555.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00603_19990303_20191002_hist.zip
# Extract product file: produkt_rr_stunde_19990303_20191002_00603.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00613_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_00613.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00617_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_00617.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00644_20050101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20191231_00644.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00796_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_00796.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00871_20050801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050801_20191231_00871.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00902_20061001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20191231_00902.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00934_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_00934.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_00989_20050201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050201_20191231_00989.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01024_20060801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20191231_01024.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01046_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_01046.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01078_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01078.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01241_20061201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20191231_01241.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01246_20150801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20150801_20191231_01246.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01300_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_01300.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01303_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01303.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01327_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_01327.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01590_20030701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20191231_01590.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01595_20121001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20121001_20191231_01595.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_01766_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_01766.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02027_20060601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060601_20191231_02027.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02110_20030105_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030105_20191231_02110.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02254_20050601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20191231_02254.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02473_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_02473.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02483_19951012_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19951012_20191231_02483.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02497_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_02497.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02629_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_02629.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02667_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_02667.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02810_20061201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061201_20191231_02810.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02947_20061001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20061001_20191231_02947.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02968_20081201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20081201_20191231_02968.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_02999_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_02999.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03028_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_03028.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03031_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_03031.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03081_20071201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20191231_03081.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03098_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_03098.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03215_20070601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070601_20191231_03215.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03321_20050701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050701_20191231_03321.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03339_20060901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20191231_03339.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03499_20060701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20191231_03499.txt
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03540_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_03540.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03591_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_03591.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03795_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_03795.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_03913_20040701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040701_20191231_03913.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04063_20030701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030701_20191231_04063.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04127_20050101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050101_20191231_04127.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04150_20051201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20051201_20191231_04150.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04154_20110201_20180701_hist.zip
# Extract product file: produkt_rr_stunde_20110201_20180701_04154.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04313_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_04313.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04368_20041001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041001_20191231_04368.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04371_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_04371.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04400_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_04400.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04488_20060801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060801_20191231_04488.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04692_20080301_20181201_hist.zip
# Extract product file: produkt_rr_stunde_20080301_20181201_04692.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04741_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_04741.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_04849_20050601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050601_20191231_04849.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05064_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_05064.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05347_19950901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_19950901_20191231_05347.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05360_20070701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070701_20191231_05360.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05468_20060701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20191231_05468.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05480_20030910_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20030910_20191231_05480.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05513_20050901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050901_20191231_05513.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05619_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_05619.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05699_20041101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191231_05699.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05717_20060901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20191231_05717.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_05733_20050501_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20050501_20191231_05733.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06197_20001013_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20001013_20191231_06197.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06264_20040601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040601_20191231_06264.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06276_20041101_20191102_hist.zip
# Extract product file: produkt_rr_stunde_20041101_20191102_06276.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06313_20041201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20041201_20191231_06313.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_06337_20040801_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20040801_20191231_06337.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07106_20060901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060901_20191231_07106.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07330_20051001_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20051001_20191231_07330.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07344_20060601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060601_20191231_07344.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07374_20060301_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060301_20191231_07374.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_07378_20060701_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20060701_20191231_07378.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13669_20070901_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070901_20191231_13669.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13670_20070601_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20070601_20191231_13670.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13671_20071201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20191231_13671.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13696_20071201_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20071201_20191231_13696.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13700_20080501_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20080501_20191231_13700.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_13713_20071101_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20071101_20191231_13713.txt
#
# Zip archive: ../data/original/DWD//hourly/precipitation/historical/stundenwerte_RR_15000_20110401_20191231_hist.zip
# Extract product file: produkt_rr_stunde_20110401_20191231_15000.txt

# %%
df_merged_ts.shape
# Out:
# (213225, 88)

# %%
df_merged_ts.head()
# Out:
#                      216    389    390    554    555    603    613    617    \
# time
# 1995-09-01 00:00:00    NaN    NaN    NaN    0.0    NaN    NaN    NaN    NaN
# 1995-09-01 01:00:00    NaN    NaN    NaN    0.0    NaN    NaN    NaN    NaN
# 1995-09-01 02:00:00    NaN    NaN    NaN    0.0    NaN    NaN    NaN    NaN
# 1995-09-01 03:00:00    NaN    NaN    NaN    0.0    NaN    NaN    NaN    NaN
# 1995-09-01 04:00:00    NaN    NaN    NaN    0.0    NaN    NaN    NaN    NaN
#
#                      644    796    ...  7344   7374   7378   13669  13670  \
# time                               ...
# 1995-09-01 00:00:00    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 01:00:00    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 02:00:00    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 03:00:00    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 04:00:00    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
#                      13671  13696  13700  13713  15000
# time
# 1995-09-01 00:00:00    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 01:00:00    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 02:00:00    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 03:00:00    NaN    NaN    NaN    NaN    NaN
# 1995-09-01 04:00:00    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 88 columns]

# %%
# prec or temp?
filepathname = local_ts_merged_dir + "prec_ts_merged.csv"
print("df_merged_ts is saved to: %s" % (filepathname))
df_merged_ts.to_csv(filepathname,sep=";")
# Out:
# df_merged_ts is saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_merged.csv

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(dpi= 136, figsize=(8,4))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
df_merged_ts[216].plot(ax = ax1)
df_merged_ts[2110].plot(ax = ax1)
df_merged_ts[2110].plot(ax = ax2)
df_merged_ts[1590].plot(ax = ax3)
df_merged_ts[2110].plot(ax = ax4)
plt.show()

# %% [markdown]
# **Attention: The following code creates a heatmap. This makes only sense if the data density is low, e.g. annual temperatures. Do not use it for hourly precipitation over a long period.**
#
# ```
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# # plot
# sns.set_style('ticks')
# fig1, ax1 = plt.subplots(dpi = 400, figsize = (12,24))
#
# #sns.heatmap(df_merged_ts, cmap='RdYlGn_r', annot=False, ax = ax1)
# sns.heatmap(df_merged_ts, cmap='coolwarm', annot=True, vmin = 8, vmax = 12, ax = ax1)
#
# # _r reverses the normal order of the color map 'RdYlGn'
#
# #sns.heatmap(df, cmap='coolwarm', annot=True, vmin = 8, vmax = 12, ax = ax)
# ax1.set_yticklabels(df_merged_ts.index.strftime('%Y'))
# plt.show()
# fig1.savefig('example1.png')
# ```

# %%
df_merged_ts_transposed = df_merged_ts.transpose()

# %%
df_merged_ts_transposed.index.names = ['station_id']

# %%
df_merged_ts_transposed.shape
# Out:
# (88, 213225)

# %%
df_merged_ts_transposed.head()
# Out:
# time        1995-09-01 00:00:00  1995-09-01 01:00:00  1995-09-01 02:00:00  \
# station_id
# 216                         NaN                  NaN                  NaN
# 389                         NaN                  NaN                  NaN
# 390                         NaN                  NaN                  NaN
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        1995-09-01 03:00:00  1995-09-01 04:00:00  1995-09-01 05:00:00  \
# station_id
# 216                         NaN                  NaN                  NaN
# 389                         NaN                  NaN                  NaN
# 390                         NaN                  NaN                  NaN
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        1995-09-01 06:00:00  1995-09-01 07:00:00  1995-09-01 08:00:00  \
# station_id
# 216                         NaN                  NaN                  NaN
# 389                         NaN                  NaN                  NaN
# 390                         NaN                  NaN                  NaN
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        1995-09-01 09:00:00  ...  2019-12-31 14:00:00  \
# station_id                       ...
# 216                         NaN  ...                  0.0
# 389                         NaN  ...                  0.0
# 390                         NaN  ...                  0.0
# 554                         0.0  ...                  0.0
# 555                         NaN  ...                  NaN
#
# time        2019-12-31 15:00:00  2019-12-31 16:00:00  2019-12-31 17:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 18:00:00  2019-12-31 19:00:00  2019-12-31 20:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 21:00:00  2019-12-31 22:00:00  2019-12-31 23:00:00
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# [5 rows x 213225 columns]

# %%
filepathname = local_ts_merged_dir + "prec_ts_merged_transposed.csv"
print("df_merged_ts_transposed is saved to: %s" % (filepathname))
df_merged_ts_transposed.to_csv(filepathname,sep=";")
# Out:
# df_merged_ts_transposed is saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_merged_transposed.csv

# %%
df_merged_ts_transposed.iloc[2,:4]
# Out:
# time
# 1995-09-01 00:00:00   NaN
# 1995-09-01 01:00:00   NaN
# 1995-09-01 02:00:00   NaN
# 1995-09-01 03:00:00   NaN
# Name: 390, dtype: float64

# %%
df_merged_ts_transposed_last_day = df_merged_ts_transposed.iloc[:,-24:]

# %%
df_merged_ts_transposed_last_day.shape
# Out:
# (88, 24)

# %%
df_merged_ts_transposed_last_day.head()
# Out:
# time        2019-12-31 00:00:00  2019-12-31 01:00:00  2019-12-31 02:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 03:00:00  2019-12-31 04:00:00  2019-12-31 05:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 06:00:00  2019-12-31 07:00:00  2019-12-31 08:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 09:00:00  ...  2019-12-31 14:00:00  \
# station_id                       ...
# 216                         0.1  ...                  0.0
# 389                         0.0  ...                  0.0
# 390                         0.0  ...                  0.0
# 554                         0.0  ...                  0.0
# 555                         NaN  ...                  NaN
#
# time        2019-12-31 15:00:00  2019-12-31 16:00:00  2019-12-31 17:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 18:00:00  2019-12-31 19:00:00  2019-12-31 20:00:00  \
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# time        2019-12-31 21:00:00  2019-12-31 22:00:00  2019-12-31 23:00:00
# station_id
# 216                         0.0                  0.0                  0.0
# 389                         0.0                  0.0                  0.0
# 390                         0.0                  0.0                  0.0
# 554                         0.0                  0.0                  0.0
# 555                         NaN                  NaN                  NaN
#
# [5 rows x 24 columns]

# %%
filepathname = local_ts_merged_dir + "prec_ts_merged_transposed_last_day.csv"
print("df_merged_ts_transposed_last_day saved to: %s" % (filepathname))
df_merged_ts_transposed_last_day.to_csv(filepathname,sep=";")
# Out:
# df_merged_ts_transposed_last_day saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_merged_transposed_last_day.csv

# %%
def ts_append():
    # Very compact code.
    df = pd.DataFrame()
    for elt in local_zip_
00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-02 02:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-02 03:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-02 04:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-02 05:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# ...                                      ...                  ...
# 2004-10-20 14:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 15:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 16:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 17:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 18:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 19:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 20:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 21:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 22:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-20 23:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 00:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 01:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 02:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 03:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 04:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 05:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 06:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 07:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 08:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 09:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 10:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 11:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 12:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 13:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 14:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 15:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 16:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 17:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 18:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
# 2004-10-21 19:00:00  Attendorn-Neulisternohl  Nordrhein-Westfalen
#
# [500 rows x 13 columns]

# %%
filepathname = local_ts_appended_dir + "prec_ts_appended.csv"
print("df_appended_ts saved to: %s" % (filepathname))
df_appended_ts.to_csv(filepathname,sep=";")
# Out:
# df_appended_ts saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_appended.csv

# %%
type(df_appended_ts.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
type(df_appended_ts.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df0 = df_appended_ts[["stations_id","r1","longitude", "altitude", "latitude"]]
df0.head()
# Out:
#                      stations_id   r1  longitude  altitude  latitude
# mess_datum
# 2004-10-01 00:00:00          216  0.0     7.8807       298   51.1143
# 2004-10-01 01:00:00          216  0.0     7.8807       298   51.1143
# 2004-10-01 02:00:00          216  0.0     7.8807       298   51.1143
# 2004-10-01 03:00:00          216  0.0     7.8807       298   51.1143
# 2004-10-01 04:00:00          216  0.0     7.8807       298   51.1143

# %%
idx1 = (df0.index >= '2017-04-16 00:00:00') & (df0.index < '2017-08-16 00:00:00') 
# df_appended_ts_April_to_Aug = df_appended_ts[idx][["stations_id","r1","longitude", "latitude"]]
df_appended_ts_April_to_Aug_Altitude = df_appended_ts[idx][["stations_id","r1", "altitude"]]
filepathname = local_ts_appended_dir + "prec_ts_appended_April_to_Aug_Altitude.csv"
print("df_appended_ts_April_to_Aug saved to: %s" % (filepathname))
df_appended_ts_April_to_Aug_Altitude.to_csv(filepathname,sep=";")
# Out:
# df_appended_ts_April_to_Aug saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_appended_April_to_Aug_Altitude.csv

# %%
df_appended_ts_April_to_Aug_Altitude.head()
# Out:
#                      stations_id   r1  altitude
# mess_datum
# 2017-04-16 00:00:00          216  0.0       298
# 2017-04-16 01:00:00          216  0.1       298
# 2017-04-16 02:00:00          216  0.1       298
# 2017-04-16 03:00:00          216  0.0       298
# 2017-04-16 04:00:00          216  0.0       298

# %%
# datetime.fromisoformat(...)

# %%
df_appended_ts[["stations_id","r1","longitude", "latitude"]]
# Out:
#                      stations_id   r1  longitude  latitude
# mess_datum
# 2004-10-01 00:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 01:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 02:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 03:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 04:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 05:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 06:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 07:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 08:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 09:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 10:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 11:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 12:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 13:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 14:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 15:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 16:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 17:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 18:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 19:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 20:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 21:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 22:00:00          216  0.0     7.8807   51.1143
# 2004-10-01 23:00:00          216  0.0     7.8807   51.1143
# 2004-10-02 00:00:00          216  0.0     7.8807   51.1143
# 2004-10-02 01:00:00          216  0.0     7.8807   51.1143
# 2004-10-02 02:00:00          216  0.1     7.8807   51.1143
# 2004-10-02 03:00:00          216  3.2     7.8807   51.1143
# 2004-10-02 04:00:00          216  0.0     7.8807   51.1143
# 2004-10-02 05:00:00          216  0.0     7.8807   51.1143
# ...                          ...  ...        ...       ...
# 2019-12-30 18:00:00        15000  0.0     6.0244   50.7983
# 2019-12-30 19:00:00        15000  0.0     6.0244   50.7983
# 2019-12-30 20:00:00        15000  0.0     6.0244   50.7983
# 2019-12-30 21:00:00        15000  0.0     6.0244   50.7983
# 2019-12-30 22:00:00        15000  0.0     6.0244   50.7983
# 2019-12-30 23:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 00:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 01:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 02:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 03:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 04:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 05:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 06:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 07:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 08:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 09:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 10:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 11:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 12:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 13:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 14:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 15:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 16:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 17:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 18:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 19:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 20:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 21:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 22:00:00        15000  0.0     6.0244   50.7983
# 2019-12-31 23:00:00        15000  0.0     6.0244   50.7983
#
# [11581404 rows x 4 columns]

# %%
df = df_appended_ts.copy(deep=True)

# %%
d3 = datetime.fromisoformat('2019-07-08 02:00:00')

# %%
type(d3)
# Out:
# datetime.datetime

# %%
idx = (df_appended_ts.index >= '2017-04-16 00:00:00') & (df_appended_ts.index < '2017-08-16 00:00:00')

# %%
# df_appended_ts_April_to_Aug = df_appended_ts[idx][["stations_id","r1","longitude", "latitude"]]
df_appended_ts_April_to_Aug = df_appended_ts[idx][["stations_id","r1"]]

# %%
filepathname = local_ts_appended_dir + "prec_ts_appended_April_to_Aug.csv"
print("df_appended_ts_April_to_Aug saved to: %s" % (filepathname))
df_appended_ts_April_to_Aug.to_csv(filepathname,sep=";")
# Out:
# df_appended_ts_April_to_Aug saved to: ../data/generated/DWD//hourly/precipitation/historical/prec_ts_appended_April_to_Aug.csv

# %%
df_appended_ts_April_to_Aug.head()
# Out:
#                      stations_id   r1
# mess_datum
# 2017-04-16 00:00:00          216  0.0
# 2017-04-16 01:00:00          216  0.1
# 2017-04-16 02:00:00          216  0.1
# 2017-04-16 03:00:00          216  0.0
# 2017-04-16 04:00:00          216  0.0

# %%
df = pd.DataFrame(data=df_appended_ts_April_to_Aug)

# %%
df1 = df.reset_index().pivot(index='mess_datum', columns='stations_id', values='r1').resample('D').sum().loc[:,[216,2947,5468,1300,4488,2483,3215,6264,7330]]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 122 entries, 2017-04-16 to 2017-08-15
# Freq: D
# Data columns (total 10 columns):
# 216       122 non-null float64
# 2947      122 non-null float64
# 5468      122 non-null float64
# 1300      122 non-null float64
# 4488      122 non-null float64
# 2483      122 non-null float64
# 3215      122 non-null float64
# 6264      122 non-null float64
# 7330      122 non-null float64
# cumsum    122 non-null float64
# dtypes: float64(10)
# memory usage: 10.5 KB

# %%
df1.columns
# Out:
# Index([216, 2947, 5468, 1300, 4488, 2483, 3215, 6264, 7330, 'cumsum'], dtype='object', name='stations_id')

# %%
del df1['cumsum']

# %%
df3 = df1.reset_index().melt(id_vars=["mess_datum"], var_name = "stations_id", value_name = "r1")
df3.head(10)
# Out:
#   mess_datum stations_id    r1
# 0 2017-04-16         216   4.3
# 1 2017-04-17         216  14.6
# 2 2017-04-18         216   2.6
# 3 2017-04-19         216   0.0
# 4 2017-04-20         216   0.0
# 5 2017-04-21         216   0.0
# 6 2017-04-22         216   2.3
# 7 2017-04-23         216   0.0
# 8 2017-04-24         216   0.0
# 9 2017-04-25         216   0.7

# %%
df3["cumsum"] = df3.groupby(["stations_id"]).cumsum()
df3.head()
# Out:
#   mess_datum stations_id    r1  cumsum
# 0 2017-04-16         216   4.3     4.3
# 1 2017-04-17         216  14.6    18.9
# 2 2017-04-18         216   2.6    21.5
# 3 2017-04-19         216   0.0    21.5
# 4 2017-04-20         216   0.0    21.5

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(df3, col="stations_id", hue="stations_id", palette="tab20c",
                     col_wrap=4, height=5, sharex=False)

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.bar, "mess_datum", "r1")
#grid.map(plt.plot, "mess_datum", "cumsum")

xformatter = mdates.DateFormatter("%Y-%m")
for i in grid.axes:
    i.xaxis.set_major_formatter(xformatter)

# Adjust the tick positions and labels
#grid.set(xticks=np.arange(5), yticks=[-3, 3],
#         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(df3, col="stations_id", hue="stations_id", palette="tab20c",
                     col_wrap=4, height=5, sharex=False)

# Draw a line plot to show the trajectory of each random walk
#grid.map(plt.bar, "mess_datum", "r1")
grid.map(plt.plot, "mess_datum", "cumsum")

xformatter = mdates.DateFormatter("%m/%y")
#grid.fig.autofmt_xdate()
    
for i in grid.axes:
    i.xaxis.set_major_formatter(xformatter)

# Adjust the tick positions and labels
#grid.set(xticks=np.arange(5), yticks=[-3, 3],
#         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)

# %%
type(grid.axes)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(2,2,figsize=(16,8), constrained_layout=False)
ax[0,0].bar(df1.index, df1[216],label='216')
ax[0,0].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[0,0].xaxis.set_major_formatter(xfmt)
ax[0,0].set_ylabel('Daily Precipitation (mm)')
ax[0,0].legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[0,1].bar(df1.index, df1[2947],label='2947')
ax[0,1].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[0,1].xaxis.set_major_formatter(xfmt)
ax[0,1].set_ylabel('Daily Precipitation (mm)')
ax[0,1].legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[1,0].bar(df1.index, df1[5468],label='5468')
ax[1,0].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[1,0].xaxis.set_major_formatter(xfmt)
ax[1,0].set_ylabel('Daily Precipitation (mm)')
ax[1,0].set_xlabel('Dates')
ax[1,0].legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[1,1].bar(df1.index, df1[1300],label='1300')
ax[1,1].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[1,1].xaxis.set_major_formatter(xfmt)
ax[1,1].set_ylabel('Daily Precipitation (mm)')
ax[1,1].set_xlabel('Dates')
ax[1,1].legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)

# autorotate the xlabels
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots(2,2,figsize=(16,8), constrained_layout=False)
ax[0,0].bar(df1.index, df1[4488],label='4488')
ax[0,0].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[0,0].xaxis.set_major_formatter(xfmt)
ax[0,0].set_ylabel('Daily Precipitation (mm)')
ax[0,0].legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[0,1].bar(df1.index, df1[2483],label='2483')
ax[0,1].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[0,1].xaxis.set_major_formatter(xfmt)
ax[0,1].set_ylabel('Daily Precipitation (mm)')
ax[0,1].legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[1,0].bar(df1.index, df1[3215],label='3215')
ax[1,0].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[1,0].xaxis.set_major_formatter(xfmt)
ax[1,0].set_ylabel('Daily Precipitation (mm)')
ax[1,0].set_xlabel('Dates')
ax[1,0].legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)

ax[1,1].bar(df1.index, df1[6264],label='6264')
ax[1,1].xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax[1,1].xaxis.set_major_formatter(xfmt)
ax[1,1].set_ylabel('Daily Precipitation (mm)')
ax[1,1].set_xlabel('Dates')
ax[1,1].legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)

# autorotate the xlabels
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots(figsize=(7,4), constrained_layout=False)
ax.bar(df1.index, df1[7330],label='7330')
ax.xaxis.set_major_locator(mdates.MonthLocator(bymonthday=-1))
xfmt = mdates.DateFormatter('%B %d, %Y')
ax.xaxis.set_major_formatter(xfmt)
ax.set_ylabel('Daily Precipitation (mm)')
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
ax.set_xlabel('Dates')
# autorotate the xlabels
fig.autofmt_xdate()

# %%
df2 = df.reset_index().pivot(index='mess_datum', columns='stations_id', values='r1').resample('D').cumsum().loc[:,[216,2947,5468,1300,4488,2483,3215,6264,7330]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-921a822efc42> in <module>
# ----> 1 df2 = df.reset_index().pivot(index='mess_datum', columns='stations_id', values='r1').resample('D').cumsum().loc[:,[216,2947,5468,1300,4488,2483,3215,6264,7330]]
#
# D:\conda\lib\site-packages\pandas\core\resample.py in __getattr__(self, attr)
#      99             return self[attr]
#     100
# --> 101         return object.__getattribute__(self, attr)
#     102
#     103     def __iter__(self):
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'cumsum'

# %%
fig = plt.figure(dpi= 136, figsize=(16,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
df1[216].plot(ax = ax1, kind='bar')
df1[2947].plot(ax = ax2, kind='bar')
df1[5468].plot(ax = ax3, kind='bar')
df1[1300].plot(ax = ax4, kind='bar')
plt.show()

# %%
fig = plt.figure(dpi= 136, figsize=(16,8))
ax5 = fig.add_subplot(221)
ax6 = fig.add_subplot(222)
ax7 = fig.add_subplot(223)
ax8 = fig.add_subplot(224)
#ax9 = fig.add_subplot(331)
df1[2483].plot(ax = ax5)
df1[2947].plot(ax = ax5)
df1[3215].plot(ax = ax6)
df1[6264].plot(ax = ax7)
df1[7330].plot(ax = ax8)
plt.tight_layout()
plt.show()
